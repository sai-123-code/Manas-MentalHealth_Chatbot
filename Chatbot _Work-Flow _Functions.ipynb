# %% [markdown]
# # Installing Libraries

# %%
pip install python-git
# Out:
# Collecting python-gitNote: you may need to restart the kernel to use updated packages.
#
#   Downloading python_git-2018.2.1-py3-none-any.whl (10 kB)
# Collecting send2trash
#   Using cached Send2Trash-1.8.0-py3-none-any.whl (18 kB)
# Installing collected packages: send2trash, python-git
# Successfully installed python-git-2018.2.1 send2trash-1.8.0

# %%
pip install spacy==2.3.5
# Out:
# Collecting spacy==2.3.5
#   Downloading spacy-2.3.5-cp38-cp38-win_amd64.whl (9.7 MB)
# Collecting plac<1.2.0,>=0.9.6
#   Downloading plac-1.1.3-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: setuptools in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (58.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (2.26.0)
# Collecting catalogue<1.1.0,>=0.0.7
#   Downloading catalogue-1.0.0-py2.py3-none-any.whl (7.7 kB)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (0.8.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (3.0.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (2.0.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (1.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (1.21.4)
# Collecting srsly<1.1.0,>=1.0.2
#   Downloading srsly-1.0.5-cp38-cp38-win_amd64.whl (178 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (4.62.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy==2.3.5) (0.7.5)
# Collecting thinc<7.5.0,>=7.4.1
#   Downloading thinc-7.4.5-cp38-cp38-win_amd64.whl (910 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy==2.3.5) (3.3)
# Requirement already satisfied: colorama in c:\users\garlapati.varun\chatbot\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==2.3.5) (0.4.4)
# Installing collected packages: srsly, plac, catalogue, thinc, spacy
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\Garlapati.Varun\\chatbot\\Lib\\site-packages\\~rsly\\msgpack\\_packer.cp38-win_amd64.pyd'
# Check the permissions.
#     Uninstalling srsly-2.4.2:
#       Successfully uninstalled srsly-2.4.2

# %%
pip install https://github.com/MartinoMensio/spacy-universal-sentence-encoder-tfhub/releases/download/en_use_md-0.2.0/en_use_md-0.2.0.tar.gz
# Out:
# Collecting https://github.com/MartinoMensio/spacy-universal-sentence-encoder-tfhub/releases/download/en_use_md-0.2.0/en_use_md-0.2.0.tar.gzNote: you may need to restart the kernel to use updated packages.
#   ERROR: Error [WinError 2] The system cannot find the file specified while executing command git version
# ERROR: Cannot find command 'git' - do you have 'git' installed and in your PATH?
#   Downloading https://github.com/MartinoMensio/spacy-universal-sentence-encoder-tfhub/releases/download/en_use_md-0.2.0/en_use_md-0.2.0.tar.gz (12.0 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting universal_sentence_encoder@ git+ssh://git@github.com/MartinoMensio/spacy-universal-sentence-embedding-tfhub
#   Cloning ssh://****@github.com/MartinoMensio/spacy-universal-sentence-embedding-tfhub to c:\users\garlapati.varun\appdata\local\temp\pip-install-65jfz4fm\universal-sentence-encoder_317e28a8306d45e7b4b11cb71771ecac

# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.2.0-cp38-cp38-win_amd64.whl (12.1 MB)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy) (1.21.4)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Using cached pydantic-1.8.2-cp38-cp38-win_amd64.whl (2.0 MB)
# Collecting srsly<3.0.0,>=2.4.1
#   Using cached srsly-2.4.2-cp38-cp38-win_amd64.whl (452 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Using cached spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy) (4.62.3)
# Collecting pathy>=0.3.5
#   Using cached pathy-0.6.1-py3-none-any.whl (42 kB)
# Collecting cymem<2.1.0,>=2.0.2
#   Using cached cymem-2.0.6-cp38-cp38-win_amd64.whl (36 kB)
# Requirement already satisfied: setuptools in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy) (58.3.0)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.2.1.tar.gz (173 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting blis<0.8.0,>=0.4.0
#   Using cached blis-0.7.5-cp38-cp38-win_amd64.whl (6.6 MB)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.13-cp38-cp38-win_amd64.whl (1.0 MB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Using cached murmurhash-1.0.6-cp38-cp38-win_amd64.whl (21 kB)
# Collecting wasabi<1.1.0,>=0.8.1
#   Using cached wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting typer<0.5.0,>=0.3.0
#   Using cached typer-0.4.0-py3-none-any.whl (27 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Collecting jinja2
#   Downloading Jinja2-3.0.3-py3-none-any.whl (133 kB)
# Collecting preshed<3.1.0,>=3.0.2
#   Using cached preshed-3.0.6-cp38-cp38-win_amd64.whl (113 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy) (21.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy) (2.26.0)
# Collecting catalogue<2.1.0,>=2.0.6
#   Using cached catalogue-2.0.6-py3-none-any.whl (17 kB)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Collecting smart-open<6.0.0,>=5.0.0
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: colorama in c:\users\garlapati.varun\chatbot\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.0.3)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.0.1-cp38-cp38-win_amd64.whl (14 kB)
# Building wheels for collected packages: langcodes
#   Building wheel for langcodes (setup.py): started
#   Building wheel for langcodes (setup.py): finished with status 'done'
#   Created wheel for langcodes: filename=langcodes-3.2.1-py3-none-any.whl size=169396 sha256=7fafe664145c3a0e4847b1a5fafb1689e836716868d67e52d1312466a5dbaee2
#   Stored in directory: c:\users\garlapati.varun\appdata\local\pip\cache\wheels\aa\5b\45\2e2ebdd7b888ba82dac447122f8ea0f4a2404910516d486679
# Successfully built langcodes
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, MarkupSafe, blis, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, jinja2, spacy
# Successfully installed MarkupSafe-2.0.1 blis-0.7.5 catalogue-2.0.6 cymem-2.0.6 jinja2-3.0.3 langcodes-3.2.1 murmurhash-1.0.6 pathy-0.6.1 preshed-3.0.6 pydantic-1.8.2 smart-open-5.2.1 spacy-3.2.0 spacy-legacy-3.0.8 spacy-loggers-1.0.1 srsly-2.4.2 thinc-8.0.13 typer-0.4.0 wasabi-0.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyresparser
# Out:
# Collecting pyresparser
#   Using cached pyresparser-1.0.6-py3-none-any.whl (4.2 MB)
# Collecting jsonschema>=3.0.1
#   Using cached jsonschema-4.2.1-py3-none-any.whl (69 kB)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (1.3.4)
# Requirement already satisfied: blis>=0.2.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (0.7.5)
# Collecting pyrsistent>=0.15.2
#   Using cached pyrsistent-0.18.0-cp38-cp38-win_amd64.whl (62 kB)
# Requirement already satisfied: urllib3>=1.25.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (1.26.7)
# Requirement already satisfied: six>=1.12.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (1.16.0)
# Collecting sortedcontainers>=2.1.0
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: numpy>=1.16.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (1.21.4)
# Collecting pycryptodome>=3.8.2
#   Using cached pycryptodome-3.11.0-cp35-abi3-win_amd64.whl (1.8 MB)
# Collecting chardet>=3.0.4
#   Using cached chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting pdfminer.six>=20181108
#   Using cached pdfminer.six-20211012-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: idna>=2.8 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (3.3)
# Requirement already satisfied: thinc>=7.0.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (8.0.13)
# Collecting docx2txt>=0.7
#   Using cached docx2txt-0.8.tar.gz (2.8 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.22.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (2.26.0)
# Requirement already satisfied: nltk>=3.4.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (3.6.5)
# Requirement already satisfied: srsly>=0.0.7 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (2.4.2)
# Requirement already satisfied: pytz>=2019.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (2021.3)
# Requirement already satisfied: cymem>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (2.0.6)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (2.8.2)
# Requirement already satisfied: tqdm>=4.32.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (4.62.3)
# Collecting attrs>=19.1.0
#   Using cached attrs-21.2.0-py2.py3-none-any.whl (53 kB)
# Requirement already satisfied: wasabi>=0.2.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (0.8.2)
# Requirement already satisfied: preshed>=2.0.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (3.0.6)
# Requirement already satisfied: spacy>=2.1.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (3.2.0)
# Requirement already satisfied: certifi>=2019.6.16 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyresparser) (2021.10.8)
# Collecting importlib-resources>=1.4.0
#   Using cached importlib_resources-5.4.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: joblib in c:\users\garlapati.varun\chatbot\lib\site-packages (from nltk>=3.4.3->pyresparser) (1.1.0)
# Requirement already satisfied: click in c:\users\garlapati.varun\chatbot\lib\site-packages (from nltk>=3.4.3->pyresparser) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from nltk>=3.4.3->pyresparser) (2021.11.2)
# Collecting cryptography
#   Downloading cryptography-35.0.0-cp36-abi3-win_amd64.whl (2.1 MB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from preshed>=2.0.1->pyresparser) (1.0.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests>=2.22.0->pyresparser) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (21.2)
# Requirement already satisfied: setuptools in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (58.3.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (3.2.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (0.4.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (1.0.1)
# Requirement already satisfied: jinja2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (3.0.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (0.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy>=2.1.4->pyresparser) (3.0.8)
# Requirement already satisfied: colorama in c:\users\garlapati.varun\chatbot\lib\site-packages (from tqdm>=4.32.2->pyresparser) (0.4.4)
# Collecting zipp>=3.1.0
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from packaging>=20.0->spacy>=2.1.4->pyresparser) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pathy>=0.3.5->spacy>=2.1.4->pyresparser) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy>=2.1.4->pyresparser) (3.10.0.2)
# Collecting cffi>=1.12
#   Using cached cffi-1.15.0-cp38-cp38-win_amd64.whl (179 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from jinja2->spacy>=2.1.4->pyresparser) (2.0.1)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (setup.py): started
#   Building wheel for docx2txt (setup.py): finished with status 'done'
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3980 sha256=53208570c04a3c092265485723c2c07e3cf0a37dc3d45244d6e4f26a2c2c949b
#   Stored in directory: c:\users\garlapati.varun\appdata\local\pip\cache\wheels\55\f0\2c\81637d42670985178b77df6d41b9b6c6dc18c94818447414b9
# Successfully built docx2txt
# Installing collected packages: pycparser, zipp, cffi, pyrsistent, importlib-resources, cryptography, chardet, attrs, sortedcontainers, pycryptodome, pdfminer.six, jsonschema, docx2txt, pyresparser
# Successfully installed attrs-21.2.0 cffi-1.15.0 chardet-4.0.0 cryptography-35.0.0 docx2txt-0.8 importlib-resources-5.4.0 jsonschema-4.2.1 pdfminer.six-20211012 pycparser-2.21 pycryptodome-3.11.0 pyresparser-1.0.6 pyrsistent-0.18.0 sortedcontainers-2.4.0 zipp-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied: requests in c:\users\garlapati.varun\chatbot\lib\site-packages (from vaderSentiment) (2.26.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->vaderSentiment) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->vaderSentiment) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->vaderSentiment) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->vaderSentiment) (1.26.7)
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install spacy-universal-sentence-encoder
# Out:
# Collecting spacy-universal-sentence-encoder
#   Downloading spacy_universal_sentence_encoder-0.4.3.tar.gz (13 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: tensorflow<3.0.0,>=2.4.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy-universal-sentence-encoder) (2.7.0)
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy-universal-sentence-encoder) (3.2.0)
# Collecting tensorflow-hub
#   Downloading tensorflow_hub-0.12.0-py2.py3-none-any.whl (108 kB)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (8.0.13)
# Requirement already satisfied: setuptools in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (58.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (1.0.6)
# Requirement already satisfied: jinja2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.26.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (1.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (3.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (1.21.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (3.2.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.4.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.0.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.0.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (21.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (0.7.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (4.62.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (0.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (1.8.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (0.6.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (0.8.2)
# Requirement already satisfied: libclang>=9.0.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (12.0.0)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (3.10.0.2)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.13.3)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (3.19.1)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (2.7.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.41.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.37.0)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (2.7.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.15.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (2.7.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.21.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from packaging>=20.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (5.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (1.26.7)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (3.3.4)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (2.0.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (2.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.4.6)
# Requirement already satisfied: colorama in c:\users\garlapati.varun\chatbot\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (8.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from jinja2->spacy<4.0.0,>=3.0.0->spacy-universal-sentence-encoder) (2.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\garlapati.varun\chatbot\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\garlapati.varun\chatbot\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow<3.0.0,>=2.4.0->spacy-universal-sentence-encoder) (3.1.1)
# Building wheels for collected packages: spacy-universal-sentence-encoder
#   Building wheel for spacy-universal-sentence-encoder (setup.py): started
#   Building wheel for spacy-universal-sentence-encoder (setup.py): finished with status 'done'
#   Created wheel for spacy-universal-sentence-encoder: filename=spacy_universal_sentence_encoder-0.4.3-py3-none-any.whl size=14763 sha256=24cbd9d20c3f82a51225d537a530b15cfab88574bc6bda8b6a5226ec80f9b7ad
#   Stored in directory: c:\users\garlapati.varun\appdata\local\pip\cache\wheels\46\47\ed\4dc63e35260b4c75fea227ab0bcd448d55378b5da1de8c3394
# Successfully built spacy-universal-sentence-encoder
# Installing collected packages: tensorflow-hub, spacy-universal-sentence-encoder
# Successfully installed spacy-universal-sentence-encoder-0.4.3 tensorflow-hub-0.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sentence_transformers
# Out:
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.1.0-py3-none-any.whl
# Requirement already satisfied: nltk in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (3.6.5)
# Collecting torch>=1.6.0
#   Using cached torch-1.10.0-cp38-cp38-win_amd64.whl (226.6 MB)
# Requirement already satisfied: scikit-learn in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (1.0.1)
# Requirement already satisfied: tqdm in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (4.62.3)
# Requirement already satisfied: numpy in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (1.21.4)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.96-cp38-cp38-win_amd64.whl (1.1 MB)
# Requirement already satisfied: huggingface-hub in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (0.1.2)
# Collecting torchvision
#   Using cached torchvision-0.11.1-cp38-cp38-win_amd64.whl (984 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (4.12.3)
# Requirement already satisfied: scipy in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (1.7.2)
# Requirement already satisfied: tokenizers>=0.10.3 in c:\users\garlapati.varun\chatbot\lib\site-packages (from sentence_transformers) (0.10.3)
# Requirement already satisfied: typing-extensions in c:\users\garlapati.varun\chatbot\lib\site-packages (from torch>=1.6.0->sentence_transformers) (3.10.0.2)
# Requirement already satisfied: filelock in c:\users\garlapati.varun\chatbot\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (3.3.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (6.0)
# Requirement already satisfied: sacremoses in c:\users\garlapati.varun\chatbot\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.0.46)
# Requirement already satisfied: packaging>=20.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (21.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\garlapati.varun\chatbot\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.11.2)
# Requirement already satisfied: requests in c:\users\garlapati.varun\chatbot\lib\site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2.26.0)
# Requirement already satisfied: colorama in c:\users\garlapati.varun\chatbot\lib\site-packages (from tqdm->sentence_transformers) (0.4.4)
# Requirement already satisfied: joblib in c:\users\garlapati.varun\chatbot\lib\site-packages (from nltk->sentence_transformers) (1.1.0)
# Requirement already satisfied: click in c:\users\garlapati.varun\chatbot\lib\site-packages (from nltk->sentence_transformers) (8.0.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from scikit-learn->sentence_transformers) (3.0.0)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\garlapati.varun\chatbot\lib\site-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\garlapati.varun\chatbot\lib\site-packages (from requests->transformers<5.0.0,>=4.6.0->sentence_transformers) (2.0.7)
# Requirement already satisfied: six in c:\users\garlapati.varun\chatbot\lib\site-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence_transformers) (1.16.0)
# Installing collected packages: torch, torchvision, sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.1.0 sentencepiece-0.1.96 torch-1.10.0 torchvision-0.11.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Modules from Libraries

# %%
import pandas as pd
import io
import matplotlib.pyplot as plt
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer,TfidfTransformer
import sklearn.feature_extraction.text as text
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import CountVectorizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Garlapati.Varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Garlapati.Varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Garlapati.Varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Garlapati.Varun\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# # SVM CATEGORY CLASSIFIER

# %%
def Classify_problem(msg):
    # importing libraries
    import pandas as pd
    import numpy as np
    from sklearn import svm
    from sklearn.feature_extraction.text import TfidfTransformer,TfidfVectorizer, CountVectorizer
    from nltk.corpus import stopwords
    from nltk.tokenize import word_tokenize
    from nltk.stem import WordNetLemmatizer
    from nltk import FreqDist, pos_tag
    from nltk.corpus import wordnet
    import string
    import re
    import pickle
    # text preprocessing
    tag_dict = {"J": wordnet.ADJ,"N": wordnet.NOUN,"V": wordnet.VERB,"R": wordnet.ADV}
    text = msg.replace('\d+', '')
    text = text.replace('[^\w\s]', '')
    text = text.lower()
    lemmatizer = WordNetLemmatizer()
    text=[lemmatizer.lemmatize(item,tag_dict.get(pos_tag([item])[0][1][0].upper(),wordnet.NOUN)) for item in word_tokenize(text)]
    text = ' '.join(text)

  # pickle files
    Count_Vect_ = pickle.load(open("count_vect_svm.pkl", "rb"))
    Transformer_ = pickle.load(open("transformer_svm.pkl", "rb"))
    SVM_tf = pickle.load(open("model_svm.pkl", "rb"))

    
#   Predict Probabilities With tfidf-SVM,RF
    counts = Count_Vect_.transform([text])
    counts = Transformer_.transform(counts)
    tfidf_svm= SVM_tf.predict_proba(counts)
    cls7=['Anger Management' ,'Behavioral Change', 'Counseling Fundamentals',
         'Depression' ,'Family Conflict' ,'Intimacy', 'LGBTQ',
          'Marriage', 'Parenting', 'Relationship Dissolution', 'Relationships',
        'Self-esteem' ,'Sleep Improvement' ,'Social Relationships' ,'Stress/Anxiety',
         'Substance Abuse/Addiction' ,'Trauma/Grief/Loss', 'Workplace issues']
    maxpos = tfidf_svm.argmax()
    label=cls7[maxpos]
    return label

# %%
# %%time
Manas_chatbot("My boss always hates me")
# Out:
# Wall time: 21.7 ms
# 'Workplace issues'

# %% [markdown]
# # Sentiment Analysis using Vader

# %%
def Vader_sentiment_scores(sentence):
    from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
  
    # Create a SentimentIntensityAnalyzer object.
    sid_obj = SentimentIntensityAnalyzer()
  
    # polarity_scores method of SentimentIntensityAnalyzer
    # oject gives a sentiment dictionary.
    # which contains pos, neg, neu, and compound scores.
    sentiment_dict = sid_obj.polarity_scores(sentence)
    # decide sentiment as positive, negative and neutral
    if sentiment_dict['compound'] > 0.2 :
        return("Positive")
  
    else :
        return("Negative")

# %%
# %%time
Vader_sentiment_scores("My boss always hates me")
# Out:
# Wall time: 28.5 ms
# 'Negative'

# %%
# import spacy
# nlp = spacy.load('en_use_md-0.2.0')

# search_doc = nlp("This was very strange argument between american and british person")

# main_doc = nlp("He was from Japan, but a true English gentleman in my eyes, and another one of the reasons as to why I liked going to school.")

# print(main_doc.similarity(search_doc))

# %% [markdown]
# # Sentence similarity using BERT embeddings

# %%
from sentence_transformers import SentenceTransformer
print("model-1")
model1=SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# model-1

# %%
def similarity_test(query):
    import scipy
    from sentence_transformers import SentenceTransformer
    input_msg=[query]
    model=SentenceTransformer('bert-base-nli-mean-tokens')
    input_embeddings= model.encode(input_msg)
    queries=['How can I control myself and my anger?',
       'How do I not be angry all the time?',
       'How can I control my temper?', 'Why do I get angry so easily?',
       'How do I deal with my alcoholic boyfriend with a dark past?',
       'My girlfriend always brings up past events and talks negatively about them',
       'Why did my boyfriend hit himself in the face during an argument?',
       'How can I just be happy and not mad all the time?',
       'How can I be less angry?', 'I need help controlling my anger',
       "How do I deal with my son's violent thoughts and dreams?",
       "How can I deal with the anger problems I've gained from my soon-to-be husband?",
       'How can I stop being so angry?', 'Why am I so mad?',
       'How can I control myself and learn to let things go or communicate?',
       'How can I be less confused about my feelings towards anything?',
       'I need to know how to cope with misophonia before I go completely insane',
       'i need answers to my angry, possessiveness, and urges',
       'How can I control my anger?', 'How do I manage my anger?',
       'Why am I constantly angry?',
       'My husband and I canâ€™t talk to each other without arguing',
       'Why do I get random spurts of anger over petty things?',
       'I have anger issues. I am extremely explosive about the simplest things']
    query_embeddings=model.encode(queries)
    closest_n=1
    dist_scores=[]
    for query,query_embedding in zip(queries,query_embeddings):
        distances=scipy.spatial.distance.cdist([query_embedding],input_embeddings,"cosine")[0]
        score=(1-distances)
        dist_scores.extend(score)
    return max(dist_scores)
#         if score >0.75:
#             print("Matched strings :",query)
#     print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")

# %%
similarity_test("My boss hates me")
# Out:
# Max Scores [0.14089822060750334, 0.12155116672358479, 0.21725896156051272, 0.3775604259665062, 0.14220673823691632, 0.13601045159336167, 0.1968304479226619, 0.19880535096302454, 0.25381272950909284, 0.22642692507643392, 0.2651590120088514, 0.1796816294215594, 0.13498585127696505, 0.1842371808646699, 0.2511316485802002, 0.11762472848773298, 0.21483247103211944, 0.18037582137856367, 0.1459745082193552]
# Max score index 3

# %% [markdown]
# # Data Visualization of Counsel chat data

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\Garlapati.Varun\\Downloads\\Manas\\Answers.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0  questionID                                      questionTitle  \
# 0           0           0  Can I change my feeling of being worthless to ...
# 1           1           0  Can I change my feeling of being worthless to ...
# 2           2           0  Can I change my feeling of being worthless to ...
# 3           3           0  Can I change my feeling of being worthless to ...
# 4           4           0  Can I change my feeling of being worthless to ...
#
#                                         questionText  \
# 0  I'm going through some things with my feelings...
# 1  I'm going through some things with my feelings...
# 2  I'm going through some things with my feelings...
# 3  I'm going through some things with my feelings...
# 4  I'm going through some things with my feelings...
#
#                                         questionLink       topic  \
# 0  https://counselchat.com/questions/can-i-change...  depression
# 1  https://counselchat.com/questions/can-i-change...  depression
# 2  https://counselchat.com/questions/can-i-change...  depression
# 3  https://counselchat.com/questions/can-i-change...  depression
# 4  https://counselchat.com/questions/can-i-change...  depression
#
#                                        therapistInfo  \
# 0  Sherry Katz, LCSWCouples and Family Therapist,...
# 1  Robin Landwehr, DBH, LPCC, NCCMental Health in...
# 2  Lee KingI use an integrative approach to treat...
# 3  Shauntai Davis-YearginPersonalized, private on...
# 4  Jordan WhiteLicensed Social Worker at Oak Root...
#
#                                         therapistURL  \
# 0  https://counselchat.com/therapists/sherry-katz...
# 1  https://counselchat.com/therapists/robin-landw...
# 2        https://counselchat.com/therapists/lee-king
# 3  https://counselchat.com/therapists/shauntai-da...
# 4    https://counselchat.com/therapists/jordan-white
#
#                                           answerText  upvotes  views  split
# 0  If everyone thinks you're worthless, then mayb...        1   2899  train
# 1  Hello, and thank you for your question and see...        1   3514  train
# 2  First thing I'd suggest is getting the sleep y...        0      5  train
# 3  Therapy is essential for those that are feelin...        0     31  train
# 4  I first want to let you know that you are not ...        0    620  train

# %%
# df = df[df['topic'] == 'depression']

# %%
df['questionTitle'].nunique()
# Out:
# 130

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Distribution of answers by topic
fig, ax = plt.subplots(figsize=(20, 10))
df.groupby("topic").agg("count")["questionID"].sort_values(ascending=False).plot.bar(ax=ax)
ax.set_title("Number of Responses by Topic", fontsize=30)
ax.set_xlabel("Topics", fontsize=25)
ax.set_ylabel("Number of Responses", fontsize=25)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=17)
plt.tight_layout()

# %%
# Number of questsions asked per topic
fig, ax = plt.subplots(figsize=(20, 10))
df.groupby(["topic", "questionID"]).agg("count").reset_index().groupby("topic").agg("count")["questionID"].sort_values(ascending=False).plot.bar(ax=ax)
ax.set_title("Number of Questions by Topic", fontsize=30)
ax.set_ylabel("Number of Questions", fontsize=25)
ax.set_xlabel("Topic", fontsize=25)
ax.set_xticklabels(ax.get_xticklabels(), fontsize=17)
plt.tight_layout()

# %%
# Distribution of response likes
# Distribution of empathy in responses
fig, ax = plt.subplots(figsize=(20,10))
df.groupby(["topic", "upvotes"]).agg("count").reset_index().groupby("topic").agg("count")["upvotes"].sort_values(ascending=False).plot.bar(ax=ax)
ax.set_xlabel("Topics", fontsize=15)
ax.set_ylabel("No of upvotes", fontsize=15)
ax.set_title("Distribution of Upvotes", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of Upvotes')

# %%
fig, ax = plt.subplots(figsize=(20,10))
df.groupby(["topic", "views"]).agg("count").reset_index().groupby("topic").agg("count")["views"].sort_values(ascending=False).plot.bar(ax=ax)
ax.set_xlabel("Topics", fontsize=15)
ax.set_ylabel("No of views", fontsize=15)
ax.set_title("Distribution of views", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Distribution of views')

# %%
cls7=['Anger Management' ,'Behavioral Change', 'Counseling Fundamentals',
         'Depression' ,'Family Conflict' ,'Intimacy', 'LGBTQ',
          'Marriage', 'Parenting', 'Relationship Dissolution', 'Relationships',
        'Self-esteem' ,'Sleep Improvement' ,'Social Relationships' ,'Stress/Anxiety',
         'Substance Abuse/Addiction' ,'Trauma/Grief/Loss', 'Workplace issues']

# %%
df['topic'].unique()
# Out:
# array(['depression', 'anxiety', 'parenting', 'self-esteem',
#        'relationship-dissolution', 'workplace-relationships',
#        'spirituality', 'trauma', 'domestic-violence', 'anger-management',
#        'sleep-improvement', 'intimacy', 'grief-and-loss',
#        'substance-abuse', 'family-conflict', 'marriage',
#        'eating-disorders', 'relationships', 'lgbtq', 'behavioral-change',
#        'addiction', 'legal-regulatory', 'professional-ethics', 'stress',
#        'human-sexuality', 'social-relationships', 'children-adolescents',
#        'military-issues', 'self-harm', 'diagnosis',
#        'counseling-fundamentals'], dtype=object)

# %%
anger_df = df[df['topic'] == 'anger-management']

# %%
anger_df['questionTitle'].unique()
# Out:
# array(['How can I control myself and my anger?',
#        'How do I not be angry all the time?',
#        'How can I control my temper?', 'Why do I get angry so easily?',
#        'How do I deal with my alcoholic boyfriend with a dark past?',
#        'My girlfriend always brings up past events and talks negatively about them',
#        'Why did my boyfriend hit himself in the face during an argument?',
#        'How can I just be happy and not mad all the time?',
#        'How can I be less angry?', 'I need help controlling my anger',
#        "How do I deal with my son's violent thoughts and dreams?",
#        "How can I deal with the anger problems I've gained from my soon-to-be husband?",
#        'How can I stop being so angry?', 'Why am I so mad?',
#        'How can I control myself and learn to let things go or communicate?',
#        'How can I be less confused about my feelings towards anything?',
#        'I need to know how to cope with misophonia before I go completely insane',
#        'i need answers to my angry, possessiveness, and urges',
#        'How can I control my anger?', 'How do I manage my anger?',
#        'Why am I constantly angry?',
#        'My husband and I canâ€™t talk to each other without arguing',
#        'Why do I get random spurts of anger over petty things?',
#        'I have anger issues. I am extremely explosive about the simplest things'],
#       dtype=object)

# %% [markdown]
# # CHATBOT-Response Function

# %%
def Manas_chatbot(msg):
    import pandas as pd
    msg=msg.lower()
    sentiment=Vader_sentiment_scores(msg)
    greetings = ['hi','hey', 'hello', 'heyy', 'hi', 'hey', 'good evening', 'good morning', 'good afternoon', 'good', 'fine', 'okay', 'great', 'could be better', 'not so great', 'very well thanks', 'fine and you', "i'm doing well", 'pleasure to meet you', 'hi whatsup']
    goodbyes = ['thank you', 'thank you', 'yes bye', 'bye', 'thanks and bye', 'ok thanks bye', 'goodbye', 'see ya later', 'alright thanks bye', "that's all bye", 'nice talking with you', 'i’ve gotta go', 'i’m off', 'good night', 'see ya', 'see ya later', 'catch ya later', 'adios', 'talk to you later', 'bye bye', 'all right then', 'thanks', 'thank you', 'thx', 'thx bye', 'thnks', 'thank u for ur help', 'many thanks', 'you saved my day', 'thanks a bunch', "i can't thank you enough", "you're great", 'thanks a ton', 'grateful for your help', 'i owe you one', 'thanks a million', 'really appreciate your help', 'no', 'no goodbye']
    if msg in greetings:
        answer="Hi! I\'m a Mental Health chatbot!.My name is Manas.Please ask me for help whenever you feel like it! I\'m always online."
    elif sentiment="Positive":
        answer="That's great! Do you still have any questions for me?"
    elif sentiment="Negative":
        answer="Tough to hear that.Whats your problem ?"
    elif msg in goodbyes:
        answer="Hope I was able to help you today! Take care, bye!"
    else:
        category=Classify_problem(msg)
        import pandas as pd
        df=pd.read_excel("C:\\Users\\Garlapati.Varun\\Downloads\\Manas\\Answers_short.xlsx")
        df = df[df['Topic'] == category]
        query=df['comp'].tolist()
# print(query)
        scores=[]
        for queries in query:
            a=similarity_test(queries)
            scores.append(a)
        df['scores']=scores
        df=df[df['scores']==df['scores'].max()]
        answer_out=df['Summarized answer'].tolist()
        answer_out.insert(0, "")
        answer = ''.join(answer_out)
    return answer
# Out:
#   File "C:\Users\GARLAP~1.VAR\AppData\Local\Temp/ipykernel_12096/564419044.py", line 8
#     answer="Hi! I\'m a Mental Health chatbot!.My name is Manas.Please ask me for help whenever you feel like it! I\'m always online.")
#                                                                                                                                      ^
# SyntaxError: unmatched ')'

# %% [markdown]
# # Testing Response Function

# %%
# %%time
category="Anger Management"
import pandas as pd
df=pd.read_excel("C:\\Users\\Garlapati.Varun\\Downloads\\Manas\\Answers_short.xlsx")
df = df[df['Topic'] == category]
query=df['comp'].tolist()
# print(query)
scores=[]
for queries in query:
    a=similarity_test(queries)
    scores.append(a)
df['scores']=scores
df=df[df['scores']==df['scores'].max()]
answer_out=df['Summarized answer'].tolist()
answer = ''.join(answer_out)
answer
# Out:
# Wall time: 2min 8s
# ['Being able to control your temper depends on several variables: how you saw anger acted out as a child in terms of your primary caregivers and what you internalized as being normal. I would encourage you to seek anger management from a therapist who utilizes a Cognitive Behavioral approach. In addition, engage in activities that promote stress reduction if your blowups are indeed related to being overly stressed.']
